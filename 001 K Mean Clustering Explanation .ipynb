# %% [markdown]
# ## K Means Clustering
#
# ### Method Used
# K Means Clustering is an unsupervised learning algorithm that tries to cluster data based on their similarity. Unsupervised learning means that there is no outcome to be predicted, and the algorithm just tries to find patterns in the data. In k means clustering, we have the specify the number of clusters we want the data to be grouped into. The algorithm randomly assigns each observation to a cluster, and finds the centroid of each cluster. Then, the algorithm iterates through two steps: Reassign data points to the cluster whose centroid is closest. Calculate new centroid of each cluster. These two steps are repeated till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.
#
# <br>
# <br>
#
# ### Import Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ###  Create Data with make_blobs

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8)

# %% [markdown]
# __Explore Data__

# %%
#data[0] are the points location 

data[0]
# Out:
# array([[  5.36813096,  -1.67069262],
#        [  2.09079906, -10.09472746],
#        [ -8.03372682,   6.01675315],
#        [  3.14486186,  -5.71186523],
#        [ -6.97076748,   4.12566108],
#        [ -5.02918045,   7.63107714],
#        [ -7.93004333,   3.58701679],
#        [ -8.45583087,   3.89330749],
#        [-10.96858191,   1.92507371],
#        [  7.33316507,  -1.743824  ],
#        [-11.82848371,   5.72095135],
#        [  2.73805697,  -9.56585068],
#        [  2.79009754,  -6.74076832],
#        [  3.32172131, -10.32282207],
#        [  3.63779415,  -0.45114028],
#        [  3.75843076,  -8.93347655],
#        [  4.48292379,  -7.63831393],
#        [ -8.18444737,   3.51496522],
#        [ -7.78335515,   7.17731391],
#        [-10.50456552,   2.72694205],
#        [ -4.20401901,   7.11770638],
#        [ -9.87521539,   2.96515276],
#        [  5.90504108,  -7.04826741],
#        [ -9.03791273,   0.35573573],
#        [  7.30055103,   0.93173025],
#        [ -5.98775393,   7.23644996],
#        [ -9.75846567,   3.91931575],
#        [ -9.76785691,   3.54773571],
#        [  8.53948454,  -2.04359272],
#        [  4.14289348,  -7.77238594],
#        [ -7.5370323 ,   4.5313223 ],
#        [ -0.83380268,  -6.48863518],
#        [  5.04522812,  -8.71366988],
#        [  4.99856392, -10.11886661],
#        [ -5.26433411,   0.28915119],
#        [  4.24849061,  -7.93187238],
#        [  2.38897356,  -6.45480073],
#        [  2.73656531,  -9.10193663],
#        [  7.12350687,   0.74238449],
#        [  5.15462842,  -1.57215013],
#        [ -8.67196225,   3.29115534],
#        [  4.18564315,  -8.61254265],
#        [  1.80925133,  -9.98822244],
#        [ -6.30419553,   4.49684617],
#        [-11.06884434,  -0.40593034],
#        [ -8.02259998,   1.82602069],
#        [  3.65692561,  -2.55756594],
#        [ -7.89976345,   7.17196827],
#        [  5.48643896,  -1.07939098],
#        [  7.56839347,  -0.70397963],
#        [  7.07785496,  -4.28103374],
#        [  5.13700545, -12.80028291],
#        [  1.29862693, -10.15542349],
#        [  1.95724443, -10.44868638],
#        [  8.03122525,  -2.70073021],
#        [ -5.15272984,   6.91351062],
#        [ -8.48261271,   2.06985424],
#        [  4.44651539, -11.04005009],
#        [-11.04602096,   2.05988141],
#        [  4.8813453 ,  -9.46552623],
#        [-12.60188746,   2.1563022 ],
#        [-10.50645168,   2.13528798],
#        [  6.91737801,   0.21505965],
#        [-12.28313487,  -0.23145492],
#        [  6.76931026,  -1.08297164],
#        [  5.57145341,  -0.46507564],
#        [  1.94962268,  -7.61878235],
#        [-11.87035285,   4.25964398],
#        [  6.10444421,   1.89945898],
#        [ -9.63453008,   4.76877577],
#        [  4.84203448,   1.38093023],
#        [  5.50575337,  -2.92043547],
#        [-10.68975156,   4.75103018],
#        [  6.62030613,  -1.04197376],
#        [ -4.04266181,   2.60312952],
#        [  3.15724606,  -8.66654716],
#        [ -8.30689631,   4.98670348],
#        [  5.41362594,  -8.76075134],
#        [ -2.6444721 ,   5.59984994],
#        [  7.98561738,   1.46385103],
#        [  2.63844296,  -1.41826162],
#        [ -7.92319165,   7.9904109 ],
#        [  5.58084214,  -0.58364664],
#        [  7.41618516,  -1.95462632],
#        [-10.95749429,   0.65528582],
#        [  3.56964207,  -9.52962625],
#        [  6.19144362,  -0.04371824],
#        [  3.00938745,  -7.33060535],
#        [  8.92556648,   0.04910811],
#        [  6.1014244 ,  -1.72177392],
#        [ -6.86298056,   8.11272918],
#        [  2.07017208,  -7.47094648],
#        [ -8.92819884,   4.53757243],
#        [ -5.18445335,   5.95890827],
#        [  5.26486915,   0.52027883],
#        [ -8.80965192,   4.04118209],
#        [ -7.66367071,   6.22164576],
#        [  1.35022643,  -6.50796459],
#        [ -7.69349239,   3.89514192],
#        [ -6.01306331,   5.53913737],
#        [ -4.86979477,   2.16089369],
#        [  9.19255937,  -2.81515414],
#        [-10.31505656,   3.04880665],
#        [  7.30176409,   1.11237681],
#        [ -8.83175133,   5.68518367],
#        [  0.19864411,  -6.73471809],
#        [ -8.62042508,   2.503296  ],
#        [  6.82069456,  -1.40110054],
#        [ -9.07537438,   1.92099222],
#        [ -6.08713608,   3.54968232],
#        [  9.5342764 ,  -2.8296045 ],
#        [  1.9674489 ,  -9.96229568],
#        [ -6.61493426,   3.19008521],
#        [-11.81081446,   2.03377165],
#        [ -9.23915604,   2.19370712],
#        [  3.25982571,  -9.59881639],
#        [ -7.46528349,   3.10526431],
#        [ -5.96050382,   7.60442255],
#        [  7.27126388,  -8.98628195],
#        [-13.08503951,   4.21335453],
#        [ -5.00545933,   3.09968118],
#        [  4.05958442,  -2.97939089],
#        [ -9.89618006,   2.84310578],
#        [  0.40541865,  -9.08147561],
#        [ -8.80796835,   1.01849815],
#        [ -7.87474365,   5.87738484],
#        [-10.39409187,   4.86048915],
#        [ -6.78492387,   8.96448748],
#        [  6.47517656,   1.87494118],
#        [ -6.75208842,   0.7338409 ],
#        [-10.96425805,   0.6051287 ],
#        [ -8.43382294,   1.36369416],
#        [  2.30456148,  -5.80021328],
#        [ -8.85121505,   0.71798771],
#        [  0.85685759,  -5.7791648 ],
#        [-12.99293556,   4.33358479],
#        [  7.34491329,  -6.1089887 ],
#        [  5.12643252,  -2.41765933],
#        [-10.80570897,   4.69055361],
#        [  1.21999113,  -8.11314966],
#        [ -5.06840862,   5.24329368],
#        [ -6.76846955,   5.6860458 ],
#        [-11.10554724,   1.8129345 ],
#        [ -5.23352687,   3.84701628],
#        [  8.06780744,   0.99706292],
#        [  1.67949464, -10.07062331],
#        [ -8.21060675,   0.22621865],
#        [ -7.17901342,   0.84086402],
#        [ -7.79253809,   2.67964078],
#        [ -8.89193091,  -1.53467073],
#        [-10.61507322,   0.77207406],
#        [ -6.49399051,   7.31003429],
#        [  6.75574048,   0.41438323],
#        [ -9.98689031,   1.7020436 ],
#        [ -8.20670107,   2.63257549],
#        [ -8.91965803,   4.85538749],
#        [-10.15704898,   4.25876022],
#        [ -4.10684288,   6.98782869],
#        [  5.16398425,  -0.73738099],
#        [  5.07076105,  -1.52771121],
#        [  2.08801614, -10.4456658 ],
#        [  3.94916847,  -9.06814616],
#        [ -9.88137214,   2.00359911],
#        [  4.02608158,  -0.95959309],
#        [ -6.2247449 ,   2.57082446],
#        [ -8.52005094,   3.17917181],
#        [  6.58737239,  -2.6721723 ],
#        [ -5.53451221,   7.82600323],
#        [ -9.08559858,   4.52619733],
#        [  4.52250002, -10.09338987],
#        [ -5.00919242,   3.30943582],
#        [  1.59745841,  -8.11685652],
#        [ -5.79693804,   6.51989869],
#        [  4.97221992,  -1.30742893],
#        [  2.32724596,  -7.5616154 ],
#        [  4.97714391,  -9.86285803],
#        [-10.28383228,   2.57273035],
#        [ -6.38619264,   7.59384658],
#        [  9.06925857,  -0.46568942],
#        [ -9.05805837,   1.5140105 ],
#        [  8.31129033,  -1.0342378 ],
#        [ -7.19516164,   5.60273365],
#        [-10.78452874,   3.74084368],
#        [  6.52973121,  -8.8139707 ],
#        [  5.64311678,   1.62419803],
#        [  4.0467148 ,  -4.11437786],
#        [  6.77276962,   0.44000617],
#        [  4.02774148, -11.1766862 ],
#        [  5.22288113,  -2.20377502],
#        [ -6.97731431,   7.06006729],
#        [  4.6111116 ,  -1.63158978],
#        [ -6.35536352,   4.87111023],
#        [ -5.0984634 ,   5.6945652 ],
#        [ -8.57005244,   5.45825592],
#        [  4.2989638 , -10.15435708],
#        [  6.54124666,   0.05723017],
#        [  1.08657394,  -8.29678369],
#        [  2.80391968,  -5.98182338],
#        [ -7.78902657,   3.69121353],
#        [  4.15036028,  -7.35578662]])

# %%
#data[1] are target (cluster value)

data[1]
# Out:
# array([2, 3, 1, 3, 1, 1, 1, 1, 0, 2, 0, 3, 3, 3, 2, 3, 3, 1, 1, 0, 1, 0,
#        3, 0, 2, 1, 0, 0, 2, 3, 1, 3, 3, 3, 0, 3, 3, 3, 2, 2, 0, 3, 3, 1,
#        0, 0, 2, 1, 2, 2, 2, 3, 3, 3, 2, 1, 0, 3, 0, 3, 0, 0, 2, 0, 2, 2,
#        3, 0, 2, 1, 2, 2, 0, 2, 0, 3, 1, 3, 1, 2, 2, 1, 2, 2, 0, 3, 2, 3,
#        2, 2, 1, 3, 1, 1, 2, 1, 1, 3, 0, 1, 0, 2, 0, 2, 1, 3, 0, 2, 0, 1,
#        2, 3, 1, 0, 0, 3, 0, 1, 3, 0, 1, 2, 0, 3, 0, 0, 1, 1, 2, 0, 0, 0,
#        3, 0, 3, 0, 2, 2, 0, 3, 1, 1, 0, 1, 2, 3, 0, 0, 1, 0, 0, 1, 2, 0,
#        1, 1, 0, 1, 2, 2, 3, 3, 0, 2, 1, 0, 2, 1, 1, 3, 1, 3, 1, 2, 3, 3,
#        0, 1, 2, 0, 2, 1, 0, 3, 2, 2, 2, 3, 2, 1, 2, 1, 1, 1, 3, 2, 3, 3,
#        1, 3])

# %% [markdown]
# ### Visualize Data

# %%
plt.scatter(data[0][:,0],data[0][:,1])

# %% [markdown]
# Let's discriminate through colors

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# ## Creating the Clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 3.21689494, -8.59211536],
#        [-6.28775779,  5.69140586],
#        [-9.64010562,  2.55206249],
#        [ 6.28746969, -0.92674386]])

# %%
kmeans.labels_
# Out:
# array([3, 0, 1, 0, 1, 1, 2, 2, 2, 3, 2, 0, 0, 0, 3, 0, 0, 2, 1, 2, 1, 2,
#        0, 2, 3, 1, 2, 2, 3, 0, 1, 0, 0, 0, 2, 0, 0, 0, 3, 3, 2, 0, 0, 1,
#        2, 2, 3, 1, 3, 3, 3, 0, 0, 0, 3, 1, 2, 0, 2, 0, 2, 2, 3, 2, 3, 3,
#        0, 2, 3, 2, 3, 3, 2, 3, 1, 0, 1, 0, 1, 3, 3, 1, 3, 3, 2, 0, 3, 0,
#        3, 3, 1, 0, 2, 1, 3, 2, 1, 0, 1, 1, 1, 3, 2, 3, 1, 0, 2, 3, 2, 1,
#        3, 0, 1, 2, 2, 0, 2, 1, 0, 2, 1, 3, 2, 0, 2, 1, 2, 1, 3, 2, 2, 2,
#        0, 2, 0, 2, 0, 3, 2, 0, 1, 1, 2, 1, 3, 0, 2, 2, 2, 2, 2, 1, 3, 2,
#        2, 2, 2, 1, 3, 3, 0, 0, 2, 3, 1, 2, 3, 1, 2, 0, 1, 0, 1, 3, 0, 0,
#        2, 1, 3, 2, 3, 1, 2, 0, 3, 3, 3, 0, 3, 1, 3, 1, 1, 1, 0, 3, 0, 0,
#        2, 0])

# %%
f ,(ax1, ax2) = plt.subplots(1,2,sharey=True,figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='plasma')

ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='plasma')

# %% [markdown]
# You should note, the colors are meaningless in reference between the two plots.
